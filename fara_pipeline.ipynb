# %%
import pandas as pd

folder_path = 'fara_files'

df_registrant_docs = pd.read_csv(f'{folder_path}/FARA_All_RegistrantDocs.csv', encoding="iso-8859-1")

# convert Stamped Date to datetime
df_registrant_docs['Date Stamped'] = pd.to_datetime(df_registrant_docs['Date Stamped'], errors='coerce')

# filter to 2023-01-01
df_registrant_docs[df_registrant_docs['Date Stamped'] >= pd.to_datetime('2023-01-01') ]

# Go through each URL
# Grab the PDF
    # if pakistan.csv doesn't exist, scrape everything
    # if it does, filter to only >=today
# Check if it contians the word "pakistan"
# If it does, add it to my table
# Out:
#       Date Stamped              Registrant Name  Registration Number  \
# 0       2025-12-02           McCollum, Jonathan                 6960
# 1       2025-12-02  Kashmir Action Network, LLC                 6912
# 2       2025-12-01  St. Lucia Tourism Authority                 2668
# 3       2025-12-01          Greenfield Law, LLC                 6294
# 4       2025-11-28                   LISCR, LLC                 5490
# ...            ...                          ...                  ...
# 17652   2023-01-01                  RMT SPV LLC                 7211
# 17653   2023-01-01                  RMT SPV LLC                 7211
# 17654   2023-01-01                  RMT SPV LLC                 7211
# 17655   2023-01-01                  RMT SPV LLC                 7211
# 17656   2023-01-01                  RMT SPV LLC                 7211
#
#                 Document Type    Short Form Name Foreign Principal Name  \
# 0      Supplemental Statement                NaN                    NaN
# 1      Supplemental Statement                NaN                    NaN
# 2      Supplemental Statement                NaN                    NaN
# 3      Supplemental Statement                NaN                    NaN
# 4      Supplemental Statement                NaN                    NaN
# ...                       ...                ...                    ...
# 17652              Short-Form       Huh, Michael                    NaN
# 17653               Exhibit C                NaN                    NaN
# 17654              Short-Form  Steinmetz, Robert                    NaN
# 17655  Registration Statement                NaN                    NaN
# 17656              Short-Form        Hubman, Tim                    NaN
#
#       Foreign Principal Country  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 17652                       NaN
# 17653                       NaN
# 17654                       NaN
# 17655                       NaN
# 17656                       NaN
#
#                                                      URL
# 0      https://efile.fara.gov/docs/6960-Supplemental-...
# 1      https://efile.fara.gov/docs/6912-Supplemental-...
# 2      https://efile.fara.gov/docs/2668-Supplemental-...
# 3      https://efile.fara.gov/docs/6294-Supplemental-...
# 4      https://efile.fara.gov/docs/5490-Supplemental-...
# ...                                                  ...
# 17652  https://efile.fara.gov/docs/7211-Short-Form-20...
# 17653  https://efile.fara.gov/docs/7211-Exhibit-C-202...
# 17654  https://efile.fara.gov/docs/7211-Short-Form-20...
# 17655  https://efile.fara.gov/docs/7211-Registration-...
# 17656  https://efile.fara.gov/docs/7211-Short-Form-20...
#
# [17657 rows x 8 columns]
